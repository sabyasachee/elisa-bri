# %%
import torch
from torch import nn
from data import OpinionDataset
import config
import pandas as pd
import os
import json
from models.OpinionMinerV2 import OpinionMiner
from collections import Counter, defaultdict
from evaluate import OpinionPerformance
import spacy
import re

# %%
mpqa3_doc_ids = open(os.path.join(config.MPQA3_FOLDER, "doclist")).read().strip().split("\n")

# %%
mpqa3_docs = []

for doc_id in mpqa3_doc_ids:
    doc = json.load(open(os.path.join(config.MPQA3_PROCESSED_FOLDER, doc_id, "tokenized.json")))
    mpqa3_docs.append(doc)

# %%
def is_span_overlap(span_x, span_y):
    return span_x[0] <= span_y[1] and span_y[0] <= span_x[1]

# %%
nlp = spacy.load("en_core_web_sm")

# %%
n = 100

for doc in mpqa3_docs:
    for sentence in doc:
        
        spacy_doc = nlp(re.sub("\s+", " ", sentence["text"]))
        spacy_tokens = [token.text for token in spacy_doc]
        
        if spacy_tokens != sentence["tokens"]:
            print("spacy:  {}".format(spacy_tokens))
            print("tokens: {}".format(sentence["tokens"]))
            print()
            n -= 1
        sentence["spacy_doc"] = spacy_doc
    
    if n <= 0:
        break

# %%
entity_sizes, event_sizes = [], []

for doc in mpqa3_docs:
    for sentence in doc:
        for ex in sentence["dse"]:
            if ex["target-type"] == "entity":
                entity_sizes.append(ex["target"][1] - ex["target"][0] + 1)
            elif ex["target-type"] == "event":
                event_sizes.append(ex["target"][1] - ex["target"][0] + 1)

# %%
print(Counter(entity_sizes))
print(Counter(event_sizes))
# Out:
# Counter({1: 1812, 3: 6, 2: 2})
# Counter({1: 982, 3: 2})

# %%
for doc in mpqa3_docs[:100]:
    for sentence in doc:

        target_entities, target_events = [], []
        spacy_entities = []

        for ent in sentence["spacy_doc"].ents:
            spacy_entities.append(ent.text)

        for ex in sentence["dse"]:
            target = " ".join(sentence["tokens"][ex["target"][0]: ex["target"][1] + 1])
            if ex["target-type"] == "entity":
                target_entities.append(target)
            elif ex["target-type"] == "event":
                target_events.append(target)
        
        print(sentence["text"])
        
        print("spacy entities:")
        for ent in spacy_entities:
            print("\t{}".format(ent))
        
        print("target entities:")
        for ent in target_entities:
            print("\t{}".format(ent))
        
        print("target events:")
        for event in target_events:
            print("\t{}".format(event))
        
        print()
# Out:
# ["Opinion" U.S. Human Rights Claims Only Empty Rhetoric]
# spacy entities:
# 	Opinion" U.S. Human Rights Claims Only Empty Rhetoric
# target entities:
# target events:
# 	Claims
#
# The U.S. State Department on Monday published its annual report on the status of human rights in other countries in the year 2001.
# spacy entities:
# 	The U.S. State Department
# 	Monday
# 	annual
# 	the year 2001
# target entities:
# target events:
#
# In this report, when referring to Iran, the United States repeated its allegations against the Islamic Republic but failed to provide any evidence in support of its baseless charges.
# spacy entities:
# 	Iran
# 	the United States
# 	the Islamic Republic
# target entities:
# 	charges
# 	States
# 	charges
# 	charges
# 	Iran
# target events:
# 	failed
#
# Among the unfounded allegations was the claim that the Islamic Republic enjoys no social base and is an unpopular system because of its human rights violations.
# spacy entities:
# 	the Islamic Republic
# target entities:
# 	claim
# 	allegations
# 	allegations
# target events:
#
# However, the massive participation of millions of Iranians in the grand rallies on Feb. 11 to mark the anniversary of the victory of the Islamic Revolution and defy U.S. threats against this country once again revealed the emptiness of U.S. charges against Iran.
# spacy entities:
# 	millions
# 	Iranians
# 	Feb. 11
# 	the Islamic Revolution
# 	U.S.
# 	U.S.
# 	Iran
# target entities:
# 	U.S.
# 	charges
# 	U.S.
# 	charges
# 	U.S.
# 	U.S.
# 	U.S.
# target events:
# 	threats
#
# It is quite clear that such baseless accusations are only made to tarnish the image of Iran, since it follows an independent policy and refuses to bow to U.S. domination.
# spacy entities:
# 	Iran
# 	U.S.
# target entities:
# 	it
# 	accusations
# 	policy
# 	Iran
# 	it
# target events:
# 	made
# 	tarnish
# 	follows
# 	refuses
# 	bow
# 	domination
#
# It is interesting that the U.S. State Department's annual global human rights report came this year at a time when Washington itself is being sharply criticized by most countries and international human rights organizations for the killing of a large number of innocent civilians in Afghanistan and the torture and inhuman treatment of the Taleban and Al-Qaeda prisoners at its military base at Guantanamo Bay.
# spacy entities:
# 	the U.S. State Department's
# 	annual
# 	this year
# 	Washington
# 	Afghanistan
# 	Al-Qaeda
# 	Guantanamo Bay
# target entities:
# 	Washington
# target events:
# 	killing
# 	treatment
# 	torture
#
# Indeed, the U.S Administration, which claims to advocate international human rights issues and which tries to play the role of a world policeman, is actually condoning the most atrocious human rights violations committed in the United States itself.
# spacy entities:
# 	the U.S Administration
# 	the United States
# target entities:
# 	issues
# 	Administration
# 	violations
# 	Administration
# 	Administration
# target events:
# 	play
# 	tries
# 	claims
# 	committed
# 	condoning
#
# The ugliest crimes are perpetrated against inmates in U.S. prisons, and the mistreatment of ethnic minorities by the U.S. police is so appalling that on several occasions it has led to massive riots.
# spacy entities:
# 	U.S.
# 	U.S.
# target entities:
# 	crimes
# 	it
# 	mistreatment
# 	police
# target events:
# 	perpetrated
# 	riots
# 	led
#
# For instance, a bloody riot was ignited in Cincinnati when an Afro-American youth was shot dead for no reason by police officers.
# spacy entities:
# 	Cincinnati
# 	Afro-American
# target entities:
# 	officers
# target events:
# 	shot
#
# Although the United States claims to advocate human rights, its harsh treatment of its own citizens and its hegemonic and belligerent policy towards other nations prove that the claim is just empty rhetoric.
# spacy entities:
# 	the United States
# target entities:
# 	claim
# 	policy
# 	treatment
# 	claim
# target events:
#
# Brazil hopes US will not interfere in greenhouse effect negotiations
# spacy entities:
# 	Brazil
# 	US
# target entities:
# target events:
# 	interfere
#
# Brasilia, 13 (Agencia Brasil - ABr) - President Fernando
# Henrique Cardoso said today that he does not believe the United
# States will interfere in international negotiations on
# controlling greenhouse gas emissions.
# spacy entities:
# 	Brasilia
# 	13
# 	Agencia Brasil - ABr
# 	Fernando Henrique Cardoso
# 	today
# 	the United States
# target entities:
# target events:
#
# Cardoso also said he
# believes the US is committed to joining other nations in
# fighting the problem and will adopt domestic measures, although
# they have formally renounced the Kyoto Protocol.
# spacy entities:
# 	US
# 	the Kyoto Protocol
# target entities:
# 	Protocol
# target events:
#
# Cardoso made his remarks as he sent congress a message calling
# for ratification of the Kyoto Protocol by Brazil and committing
# the country to reducing greenhouse emissions by 5.2% by 2012.
# spacy entities:
# 	congress
# 	the Kyoto Protocol
# 	Brazil
# 	5.2%
# 	2012
# target entities:
# 	Protocol
# target events:
# 	ratification
#
# The world's biggest sources of greenhouse gases are: United
# States 36%, Russia 17.4%, Japan 8.5%, Germany 7.4%, Great
# Britain 4.3%, Canada 3.3%, Italy 3.1%, Poland 3% and France
# 2.7%.
# spacy entities:
# 	United
# 	36%
# 	Russia
# 	17.4%
# 	Japan
# 	8.5%
# 	Germany
# 	7.4%
# 	Great Britain
# 	4.3%
# 	Canada
# 	3.3%
# 	Italy
# 	3.1%
# 	Poland
# 	3%
# 	France
# 	2.7%
# target entities:
# target events:
#
# Many fear violence after Zimbabwe vote
# spacy entities:
# 	Zimbabwe
# target entities:
# target events:
# 	violence
#
# HARARE, Zimbabwe Wellington Chinyama sat down in a barber's
# chair, unfolded his newspaper and without glancing up asked the
# young man trimming his hair the question that seems to be on
# virtually everyone's mind here: "So Joseph, have you prepared
# yourself for Zimbabwe's civil war?"
# spacy entities:
# 	HARARE
# 	Zimbabwe Wellington Chinyama
# 	Joseph
# 	Zimbabwe
# target entities:
# target events:
#
# As Zimbabweans go to the polls this weekend to re-elect or oust
# Robert Mugabe, the only leader the country has ever known, the
# question of who will win the election seems almost secondary to
# how the loser and his followers will respond.
# spacy entities:
# 	Zimbabweans
# 	this weekend
# 	Robert Mugabe
# target entities:
# target events:
#
# Surveys show the challenger, Morgan Tsvangirai, a trade union
# leader, ahead of Mugabe.
# spacy entities:
# 	Morgan Tsvangirai
# 	Mugabe
# target entities:
# target events:
#
# But a surge in political violence and
# accusations that the governing party changed election laws to
# rig the vote have fanned widespread concerns among Zimbabweans,
# election monitors and foreign diplomats that neither political
# party nor their supporters are prepared to accept the final
# tally.
# spacy entities:
# 	Zimbabweans
# target entities:
# 	tally
# target events:
# 	prepared
# 	accept
#
# "It does not take a vivid imagination to envision a scenario on
# the ground where either rioters or the military take to the
# streets in the days to come," an African diplomat said.
# spacy entities:
# 	the days
# 	African
# target entities:
# target events:
#
# Most disturbing are pronouncements by senior government
# officials and military leaders that they would not allow this
# former British colony to be led by Tsvangirai and his political
# party, the Movement for Democratic Change.
# spacy entities:
# 	British
# 	Tsvangirai
# 	the Movement for Democratic Change
# target entities:
# 	Tsvangirai
# 	party
# 	Change
# 	Tsvangirai
# 	party
# 	Change
# 	pronouncements
# 	officials
# 	leaders
# 	they
# target events:
# 	led
# 	led
# 	allow
#
# In a television
# interview broadcast the other day, Didymus Mutasa, a spokesman
# for Mugabe's ruling ZANU-PF party, said that he and other
# veterans of the country's independence war found the prospect of
# a Tsvangirai government intolerable.
# spacy entities:
# 	the other day
# 	Didymus Mutasa
# 	Mugabe
# 	ZANU-PF party
# target entities:
# 	prospect
# 	government
# target events:
#
# "People have said being ruled by the MDC is being ruled by Ian
# Smith," Mutasa said, referring to the prime minister of
# white-ruled Rhodesia, as the country was known before gaining
# independence in 1980.
# spacy entities:
# 	MDC
# 	Ian Smith
# 	Mutasa
# 	Rhodesia
# 	1980
# target entities:
# 	Smith
# 	MDC
# target events:
# 	ruled
# 	ruled
#
# "Under these circumstances, if there were
# to be a coup, we would support it very definitely."
# spacy entities:
# target entities:
# target events:
# 	coup
# 	it
#
# At least 34 people have died in political violence this year,
# almost all of them supporters of the Movement for Democratic
# Change.
# spacy entities:
# 	At least 34
# 	this year
# 	the Movement for Democratic Change
# target entities:
# target events:
#
# State Department officials this week accused Mugabe's
# government of numerous human rights violations during the
# election campaign, an allegation vehemently denied by ZANU-PF
# officials.
# spacy entities:
# 	State Department
# 	this week
# 	Mugabe
# 	ZANU-PF
# target entities:
# 	allegation
# 	allegation
# target events:
# 	violations
#
# A newspaper reported that Mugabe had put the armed forces on
# "high alert" and had recalled soldiers from neighboring Congo,
# where they have been deployed in that country's civil war.
# spacy entities:
# 	Mugabe
# 	Congo
# target entities:
# target events:
#
# Police Commissioner Augustine Chihuri denied the reports.
# spacy entities:
# 	Augustine Chihuri
# target entities:
# target events:
#
# Many Zimbabweans see this weekend's election as a contest
# between immovable forces: a 78-year-old autocrat desperate to
# remain in power and an opposition party dominated by restless
# young citizens weary of government corruption, food shortages
# and unemployment.
# spacy entities:
# 	Zimbabweans
# 	weekend
# 	78-year-old
# target entities:
# target events:
# 	remain
#
# "If Mugabe announces that he has won the election, I think that
# people will not believe it and will storm the castle," said
# Sibongile Mbuyiso, an opposition supporter.
# spacy entities:
# 	Mugabe
# 	Sibongile Mbuyiso
# target entities:
# 	he
# 	Mugabe
# target events:
# 	it
# 	won
#
# "But if the MDC
# wins, I believe Mugabe will announce martial law, throw
# Tsvangirai in jail for plotting to kill him and send the army
# into the streets."
# spacy entities:
# 	MDC
# 	Mugabe
# 	Tsvangirai
# target entities:
# 	Mugabe
# 	him
# target events:
#
# Government officials last month charged Tsvangirai and two other
# officials of his party with high treason for allegedly plotting
# to assassinate Mugabe.
# spacy entities:
# 	last month
# 	Tsvangirai
# 	two
# 	Mugabe
# target entities:
# 	Mugabe
# 	Tsvangirai
# 	officials
# target events:
# 	assassinate
# 	plotting
#
# That charge is based largely on a heavily
# edited videotape in which Tsvangirai refers to the "elimination"
# of Mugabe.
# spacy entities:
# 	Tsvangirai
# 	Mugabe
# target entities:
# 	Tsvangirai
# target events:
# 	elimination
#
# Tsvangirai was responding to a question posed by a Canadian
# publicist with whom he was meeting and who subsequently signed a
# contract with ZANU-PF.
# spacy entities:
# 	Tsvangirai
# 	Canadian
# 	ZANU-PF
# target entities:
# target events:
#
# Political analysts say the charges may
# have laid the groundwork for Mugabe to jail Tsvangirai as a
# last-ditch effort to stay in power should he lose the election.
# spacy entities:
# 	Mugabe
# 	Tsvangirai
# target entities:
# target events:
#
# But that outcome is certainly not a foregone conclusion.
# spacy entities:
# target entities:
# target events:
#
# Opposition officials say that 22 of their polling agents have
# been abducted in the past week, and a surge in violent attacks
# in swing districts could persuade enough opposition supporters
# to vote for ZANU-PF to ensure Mugabe's victory.
# spacy entities:
# 	22
# 	the past week
# 	ZANU-PF
# 	Mugabe
# target entities:
# target events:
#
# In addition, governing party officials have revised election
# laws and procedures in a manner that could change the outcome of
# the vote, according to independent election observers.
# spacy entities:
# target entities:
# target events:
#
# ZANU-PF officials have told election observers that they intend
# to increase the number of polling stations in rural areas
# believed to be their strongholds and reduce the number of
# stations in urban areas, where there is strong support for the
# opposition.
# spacy entities:
# 	ZANU-PF
# target entities:
# target events:
# 	opposition
#
# Observers say that could produce long voting lines
# and discourage some Tsvangirai supporters from casting ballots.
# spacy entities:
# 	Tsvangirai
# target entities:
# target events:
#
# ZANU-PF election officials also plan to use civil service
# employees to monitor the vote-counting and bar independent
# monitors from nonprofit organizations from assisting in such
# routine tasks as transporting ballot boxes to counting stations.
# spacy entities:
# 	ZANU-PF
# target entities:
# target events:
#
# A residency requirement introduced last month bans registered
# voters from casting ballots if they cannot provide leases or
# utility bills in their names.
# spacy entities:
# 	last month
# target entities:
# target events:
#
# That, according to foreign
# diplomats and Tsvangirai supporters, could disenfranchise
# hundreds of thousands of young opposition supporters who live
# with their parents.
# spacy entities:
# 	Tsvangirai
# 	hundreds of thousands
# target entities:
# target events:
# 	That
# 	disenfranchise
# 	That
#
# "Clearly, Mugabe is doing everything he can to steal this
# election," said John Makumbe, a political science professor at
# the University of Zimbabwe.
# spacy entities:
# 	Mugabe
# 	John Makumbe
# 	the University of Zimbabwe
# target entities:
# 	he
# target events:
# 	steal
# 	doing
#
# Tsvangirai said at a news conference Thursday night that if he
# won the election, he would not prosecute Mugabe.
# spacy entities:
# 	Tsvangirai
# 	Thursday
# 	night
# 	Mugabe
# target entities:
# target events:
#
# That could ease
# pressure on Mugabe to remain in power to avoid prosecution for
# his government's attack in the 1980s in Matabeleland, the home
# of the Ndebele tribe, which at the time posed the most
# significant threat to his leadership.
# spacy entities:
# 	Mugabe
# 	the 1980s
# 	Matabeleland
# 	Ndebele
# target entities:
# target events:
#
# An estimate of the number
# of people killed in the operation ranges from 10,000 to 20,000.
# spacy entities:
# 	10,000
# 	20,000
# target entities:
# target events:
#
# China Disapproves Use of 'Axis of Evil' in International Relations
# spacy entities:
# 	China
# 	'Axis of Evil' in International Relations
# target entities:
# 	Axis
# target events:
# 	Use
#
# Chinese Foreign Ministry spokesman Kong Quan said Friday that
# China disapproves of the use of such words as the "axis of evil"
# in international relations.
# spacy entities:
# 	Chinese Foreign Ministry
# 	Kong Quan
# 	Friday
# 	China
# target entities:
# 	axis
# target events:
# 	use
#
# Kong made the remark when asked to comment on the different
# views given by the New York Times and the Washington Post
# recentlyon a statement by the U.S. leader describing the
# Democratic People's Republic of Korea, Iran and Iraq as the
# "axis of evil" nations.
# spacy entities:
# 	the New York Times
# 	the Washington Post
# 	U.S.
# 	the Democratic People's Republic of Korea
# 	Iran
# 	Iraq
# target entities:
# 	axis
# 	Iran
# 	Iraq
# 	Korea
# target events:
#
# "We disapprove of the use of such words in international
# relations," said Kong, who also made the same comment when
# answering related questions earlier.
# spacy entities:
# 	Kong
# target entities:
# target events:
# 	use
#
# China has noticed that U.S. public opinion and general public do
# not agree to the wording of "axis of evil," he said, pointing
# out that the consequences are bound to be serious if the logic
# of the wording is followed.
# spacy entities:
# 	China
# 	U.S.
# target entities:
# target events:
#
# China always holds that anti-terrorism campaigns should be based
# on irrefutable evidence, and anti-terrorism attacks should not
# be expanded arbitrarily, said Kong.
# spacy entities:
# 	China
# 	Kong
# target entities:
# target events:
#
# He stressed that handling state-to-state relations should follow
# the purposes and principles of the United Nations Charter, the
# Five Principles of Peaceful Co-existence, and the principle that
# all countries should be treated on an equal footing.
# spacy entities:
# 	the United Nations Charter
# target entities:
# target events:
#
# This is the
# only manner that is conducive to safeguarding long-term peace
# and stability in the world and related regions.
# spacy entities:
# target entities:
# target events:
#
# US Secretary of State Colin Powell, described as one of the few enlightened officials in President Bush's administration, is trying to "patch up" President Bush's statements, especially his latest one in which he made reckless threats at the "axis of evil," namely Iran, Iraq and North Korea.
# spacy entities:
# 	US
# 	State
# 	Colin Powell
# 	one
# 	Bush
# 	Bush
# 	Iran
# 	Iraq
# 	North Korea
# target entities:
# 	he
# 	officials
# 	Powell
# 	axis
# 	Iran
# 	Iraq
# 	Korea
# target events:
# 	threats
# 	made
#
# A day after President Bush's threat to crush these countries and use all means to prevent them from developing weapons of mass destruction, Secretary Powell said before the Senate Foreign Relations Committee that "characterizing these counties as the axis of evil does not mean that his government intends to invade them."
# spacy entities:
# 	A day
# 	Bush
# 	Powell
# 	the Senate Foreign Relations Committee
# target entities:
# 	countries
# 	them
# 	countries
# 	them
# 	axis
# 	counties
# target events:
#
# He added: "We are prepared to initiate a dialogue, and we want to work with our friends and allies in the world on ways of dealing with such regimes."
# spacy entities:
# target entities:
# 	allies
# 	friends
# target events:
# 	work
#
# These are fine words, but they do not reflect the reality, because the hard-line wing in the US administration comprising Vice President Dick Cheney, Secretary of Defense Donald Rumsfeld, and National Security Adviser Condoleezza Rice have the final say in running affairs at the White House, and have direct influence on President Bush.
# spacy entities:
# 	US
# 	Dick Cheney
# 	Defense Donald Rumsfeld
# 	Condoleezza Rice
# 	the White House
# 	Bush
# target entities:
# 	wing
# 	Cheney
# 	Rumsfeld
# 	Rice
# target events:
#
# Oddly enough, speculations swirled in Washington that Powell listened to President Bush's speech and his threats to "the axis of evil" like any other US citizen.
# spacy entities:
# 	Washington
# 	Powell
# 	Bush
# 	US
# target entities:
# 	axis
# target events:
#
# He had not read the speech before President Bush delivered it, as he was supposed to do by virtue of his post.
# spacy entities:
# 	Bush
# target entities:
# 	he
# 	He
# target events:
# 	read
#
# The fact that he subsequently denied these speculations does not mean they are baseless.
# spacy entities:
# target entities:
# target events:
#
# At any rate, Secretary Powell's remark about the US administration's readiness to enter dialogue with these "evil" states and with Washington's friends on ways of dealing with them involves some contradictions.
# spacy entities:
# 	Powell
# 	US
# 	Washington
# target entities:
# 	contradictions
# 	friends
# 	them
# 	dialogue
# 	states
# target events:
# 	enter
#
# For he affirmed in the first speech that there would be no dialogue with Iraq until after it has accepted the return of the UN arms inspectors.
# spacy entities:
# 	first
# 	Iraq
# 	UN
# target entities:
# target events:
#
# The current US administration will consult with no one, not even its closest allies, whether in Europe or its followers in the Third World, particularly in the Arab world.
# spacy entities:
# 	US
# 	Europe
# 	Arab
# target entities:
# target events:
# 	consult
#
# The US administration has already decided to "punish" any country it believes poses a danger to the Hebrew State.
# spacy entities:
# 	US
# 	the Hebrew State
# target entities:
# target events:
#
# It lumped North Korea with Iran and Iraq as part of the "axis of evil" only to mislead Arabs and Muslims and to create the impression that Islam is not alone targeted.
# spacy entities:
# 	North Korea
# 	Iran
# 	Iraq
# 	Arabs
# 	Muslims
# 	Islam
# target entities:
# 	Iran
# 	axis
# 	Iraq
# 	Korea
# target events:
#
# The United States is these days ruled by an alliance between two main lobbies, the arms lobby and the Zionist lobby, which sees the world through the eyes of Ari'el Sharon and his extremist government.
# spacy entities:
# 	The United States
# 	these days
# 	two
# 	Zionist
# 	Sharon
# target entities:
# 	government
# 	Sharon
# target events:
#
# We therefore have to expect the worst in the near future.
# spacy entities:
# target entities:
# target events:
# 	expect
# 	have
#
# President Bush is facing a recession and an economic crisis.
# spacy entities:
# 	Bush
# target entities:
# target events:
#
# He does not want to repeat his father's mistake, being defeated in the next elections because of economic factors.
# spacy entities:
# target entities:
# target events:
# 	repeat
# 	mistake
# 	defeated
#
# He is therefore planning to trigger wars here and there to revive the flagging arms industry.
# spacy entities:
# target entities:
# 	industry
# 	He
# target events:
# 	revive
# 	wars
# 	trigger
# 	planning
#
# The United States is currently run by a typical Texan mentality, which is closer to that of cowboys than to a civilized mentality that believes in dialogue and coexistence among peoples.
# spacy entities:
# 	The United States
# 	Texan
# target entities:
# 	mentality
# 	States
# 	that
# 	which
# 	cowboys
# 	mentality
# target events:
# 	dialogue
# 	coexistence
# 	dialogue
# 	coexistence
# 	run
#
# This mentality simultaneously raises apprehensions and resentment, because international economic prosperity can be built on stability, not wars.
# spacy entities:
# target entities:
# target events:
# 	raises
# 	resentment
# 	apprehensions
#
# A catastrophe would engulf every country if the US arms industry progressed at the expense of the world's security and stability.
# spacy entities:
# 	US
# target entities:
# 	industry
# 	expense
# target events:
# 	catastrophe
# 	engulf
# 	progressed
#
# Rumsfeld Defends U.S. Treatment of Detainees in Cuba
# spacy entities:
# 	Rumsfeld Defends
# 	Cuba
# target entities:
# 	Treatment
# 	U.S.
# target events:
#
# WASHINGTON, Jan. 22 - Frustrated by an international outcry over
# the American treatment of prisoners in Cuba, Secretary of
# Defense Donald H. Rumsfeld defended the United States' conduct
# at length today and dismissed the criticism as breathless
# armchair hyperbole.
# spacy entities:
# 	WASHINGTON
# 	Jan. 22
# 	American
# 	Cuba
# 	Defense Donald H. Rumsfeld
# 	the United States'
# 	today
# target entities:
# 	conduct
# 	States
# 	conduct
# 	hyperbole
# 	criticism
# 	States
# target events:
# 	outcry
#
# "I am telling you what I believe in every inch of my body to be
# the truth, and I have spent a lot of time on secure video with
# the people down there," he told reporters, referring to the
# United States naval base at Guantanamo Bay, Cuba, where 158
# prisoners from the war in Afghanistan are being jailed.
# spacy entities:
# 	the United States
# 	Guantanamo Bay
# 	Cuba
# 	158
# 	Afghanistan
# target entities:
# target events:
#
# "I
# haven't found a single scrap of any kind of information that
# suggests that anyone has been treated anything other than
# humanely."
# spacy entities:
# target entities:
# target events:
#
# Mr. Rumsfeld spoke in an unusual briefing that stretched over an
# hour in an attempt, he said, to "tap down some of this
# hyperbole."
# spacy entities:
# 	Rumsfeld
# 	an hour
# target entities:
# 	hyperbole
# target events:
#
# It was prompted by a rising tide of international
# criticism after the Defense Department released photographs over
# the weekend that showed some of the prisoners kneeling before
# their captors, their legs in shackles, their hands bound in
# manacles, their mouths covered by surgical masks and their eyes
# blinded by large goggles with black tape.
# spacy entities:
# 	the Defense Department
# 	the weekend
# target entities:
# 	masks
# 	goggles
# 	shackles
# 	manacles
# 	Department
# target events:
# 	kneeling
# 	showed
# 	bound
# 	covered
# 	blinded
#
# His comments came as criticism swelled from abroad.
# spacy entities:
# target entities:
# target events:
#
# Critics said
# the United States was using sensory deprivation and other
# psychological control techniques to weaken the prisoners so that
# interrogations would be more fruitful.
# spacy entities:
# 	the United States
# target entities:
# 	techniques
# 	deprivation
# 	States
# target events:
# 	using
#
# The International
# Committee of the Red Cross, in a rare break with its code of not
# publicly criticizing detaining governments, said the United
# States might have violated Geneva Convention rules against
# making a spectacle of prisoners by distributing the pictures,
# which were published worldwide.
# spacy entities:
# 	The International Committee of the Red Cross
# 	the United States
# 	Geneva Convention
# target entities:
# 	spectacle
# target events:
# 	making
#
# Amnesty International sought access to the prisoners in
# Guantanamo and said they should be allowed to have lawyers.
# spacy entities:
# 	Amnesty International
# 	Guantanamo
# target entities:
# 	access
# target events:
#
# "Keeping prisoners incommunicado, sensory deprivation, the use
# of unnecessary restraint and the humiliation of people through
# tactics such as shaving them are all classic techniques employed
# to break the spirit of individuals ahead of interrogation," the
# organization said.
# spacy entities:
# target entities:
# 	use
# 	humiliation
# 	deprivation
# 	techniques
# 	tactics
# 	restraint
# target events:
# 	break
# 	shaving
# 	Keeping
#
# Several governments joined the chorus, saying the prisoners
# should be granted prisoner of war status under the Geneva
# Convention.
# spacy entities:
# 	the Geneva Convention
# target entities:
# target events:
#
# Such status would accord them the highest level of
# protections.
# spacy entities:
# target entities:
# target events:
#
# Javier Solana, the European Union foreign policy chief, said
# that despite the Sept. 11 atrocities, "changing our values and
# our way of life would be terrorism's first victory."
# spacy entities:
# 	Javier Solana
# 	the European Union
# 	Sept. 11
# 	first
# target entities:
# 	victory
# target events:
# 	changing
# 	changing
#
# The
# Netherlands also urged Washington to recognize the detainees as
# prisoners of war, saying, "In the fight, we need to uphold our
# norms and values."
# spacy entities:
# 	Netherlands
# 	Washington
# target entities:
# target events:
# 	recognize
#
# While debate raged elsewhere, Britain and Spain supported the
# United States.
# spacy entities:
# 	Britain
# 	Spain
# 	the United States
# target entities:
# 	States
# target events:
#
# Prime Minister Tony Blair's office said the three
# British prisoners at the detention center, called Camp X-Ray,
# "had no complaints about their treatment."
# spacy entities:
# 	Tony Blair
# 	three
# 	British
# 	Camp X-Ray
# target entities:
# target events:
#
# Spanish Foreign
# Minister Josep Pique said the Spanish government "does not have
# the slightest doubt regarding the position of the U.S.
# government."
# spacy entities:
# 	Spanish
# 	Josep Pique
# 	Spanish
# 	U.S.
# target entities:
# 	position
# target events:
#
# The warden at Camp X-Ray, Col. Terry Carrico, said he was
# determined at all times to maintain what he called "positive
# control" over the prisoners.
# spacy entities:
# 	Camp X-Ray
# 	Terry Carrico
# target entities:
# target events:
#
# Bill Nash, a retired Army major
# general and senior fellow at the Council on Foreign Relations,
# said this amounted to "imposing on them a psychological sense of
# isolation, domination and futility, and trying to establish the
# conditions by which you can then reward them for information, as
# oppose to punish them."
# spacy entities:
# 	Bill Nash
# 	Army
# 	the Council on Foreign Relations
# target entities:
# target events:
#
# Mr. Rumsfeld said it was "probably unfortunate" that the
# photographs were released, at least without an explanation.
# spacy entities:
# 	Rumsfeld
# target entities:
# target events:
# 	released
# 	explanation
#
# He
# said the prisoners had been photographed in a holding area just
# before their restraints were removed and they were put in their
# cages.
# spacy entities:
# target entities:
# target events:
#
# "If you want to think the worst about things, you can," he said.
# spacy entities:
# target entities:
# 	things
# target events:
#
# But he argued that whenever prisoners, especially those who are
# dangerous and suicidal, are transported, it only makes sense to
# lock them in restraints.
# spacy entities:
# target entities:
# target events:
#
# "When they are being moved from place
# to place, will they be restrained in a way so that they are less
# likely to be able to kill an American soldier?
# spacy entities:
# 	American
# target entities:
# target events:
#
# You bet.
# spacy entities:
# target entities:
# target events:
#
# Is it
# inhumane to do that?
# spacy entities:
# target entities:
# target events:
#
# No. Would it be stupid to do anything else?
# spacy entities:
# target entities:
# target events:
#
# Yes."
# spacy entities:
# target entities:
# target events:
#
# It is not clear why the United States has not officially
# designated the detainees as prisoners of war, especially since
# Mr. Rumsfeld said they are essentially being treated as such.
# spacy entities:
# 	the United States
# 	Rumsfeld
# target entities:
# target events:
#
# "They're in legal limbo," said Michael F. Noone, professor of
# military law at Catholic University.
# spacy entities:
# 	Michael F. Noone
# 	Catholic University
# target entities:
# target events:
# 	're
#
# "The United States has to
# get moving on screening these people and determining whether or
# not they're P.O.W.'s.
# spacy entities:
# 	The United States
# target entities:
# target events:
#
# There is no explanation for the delay."
# spacy entities:
# target entities:
# target events:
#
# Mr. Rumsfeld said the Pentagon's clear priority with the
# prisoners was to extract information from them to prevent future
# attacks.
# spacy entities:
# 	Rumsfeld
# 	Pentagon
# target entities:
# target events:
#
# "These people are committed terrorists," he said.
# spacy entities:
# target entities:
# 	people
# 	terrorists
# 	people
# target events:
#
# "We
# are keeping them off the street and out of the airlines and out
# of nuclear power plants and out of ports across this country and
# across other countries."
# spacy entities:
# target entities:
# target events:
#
# And yet, officials at Guantanamo have said that no interrogation
# has taken place on the base and that the prisoners do not have
# lawyers.
# spacy entities:
# 	Guantanamo
# target entities:
# 	officials
# target events:
#
# Asked what benefit the United States gets by not classifying the
# captives as prisoners of war, Mr. Rumsfeld said, "I don't know
# enough of the legal technicalities to answer your question.
# spacy entities:
# 	the United States
# 	Rumsfeld
# target entities:
# target events:
#
# I
# know that the process of gathering the intelligence information
# has not been concluded."
# spacy entities:
# target entities:
# target events:
#
# Mr. Rumsfeld said one of the complicating factors was that the
# Geneva Conventions give protection to prisoners from countries
# but not from terrorist organizations, like Al Qaeda, to which
# some of the prisoners apparently belong.
# spacy entities:
# 	Rumsfeld
# 	one
# 	the Geneva Conventions
# 	Al Qaeda
# target entities:
# target events:
#
# "To give standing under
# a Geneva Convention to a terrorist organization that's not a
# country is something that I think some of the lawyers who did
# not drop out of law school as I did worry about as a precedent,"
# he said.
# spacy entities:
# 	a Geneva Convention
# target entities:
# 	something
# target events:
#
# Officials have said the prisoners come from a range of
# countries, - Britain, Yemen, China, Saudi Arabia and Australia
# among them - and that has also complicated the legal picture.
# spacy entities:
# 	Britain
# 	Yemen
# 	China
# 	Saudi Arabia
# 	Australia
# target entities:
# target events:
#
# In Los Angeles, a federal district judge questioned today
# whether he had the authority to consider a challenge to the
# detention of the prisoners in Cuba.
# spacy entities:
# 	Los Angeles
# 	today
# 	Cuba
# target entities:
# 	detention
# target events:
#
# "I have grave doubts about whether I have jurisdiction," said
# the judge, A. Howard Matz.
# spacy entities:
# 	A. Howard Matz
# target entities:
# target events:
#
# He spoke at a hearing on a petition
# filed on Sunday by a group of lawyers, clerics and professors
# who demand that the detainees be identified, taken before a
# court and told of the charges against them.
# spacy entities:
# 	Sunday
# target entities:
# target events:
#
# Taro Kono (39), son of former Foreign Minister Yohei Kono and twice elected lower house Liberal Democratic Party member, wrote a critical comment on the US president's speech before the Japanese Diet on 19 February.
# spacy entities:
# 	Taro Kono
# 	39
# 	Yohei Kono
# 	Liberal Democratic Party
# 	US
# 	Japanese
# 	Diet
# 	19 February
# target entities:
# target events:
# 	speech
#
# The following is a translated excerpt from an article by Kono published in his e-mail magazine, Gomameno no Hagishiri ( Futile Resistance ), on 19 February.
# spacy entities:
# 	Kono
# 	Gomameno
# 	19 February
# target entities:
# target events:
#
# Kono issues his e-mail magazine almost daily.
# spacy entities:
# 	Kono
# target entities:
# target events:
#
# "During President Bush's speech, I thought of heckling; 'What are you going to do with the Kyoto Protocol?' and 'How about CTBT?' but I refrained.
# spacy entities:
# 	Bush
# 	the Kyoto Protocol
# target entities:
# target events:
# 	speech
#
# The President used the words 'common values,' but is it really true?
# spacy entities:
# target entities:
# target events:
#
# I think 'value sharing,' not 'burden sharing' or 'power sharing,' is needed for today's Japan-US relationship.
# spacy entities:
# 	today
# 	Japan
# 	US
# target entities:
# target events:
#
# The United States says the CTBT is unacceptable; that nobody cares about the BWC; that there should not be a Kyoto Protocol; that US citizens have the right to own handguns; that land mines are necessary; that the SOFA needs no revision, just a change in application; and then we should attack Iraq together.
# spacy entities:
# 	The United States
# 	BWC
# 	a Kyoto Protocol
# 	US
# 	SOFA
# 	Iraq
# target entities:
# 	CTBT
# target events:
# 	cares
# 	be
# 	attack
# 	attack
#
# This is not acceptable.
# spacy entities:
# target entities:
# target events:
#
# Ambassadors from Middle Eastern countries immediately came and asked me what I thought of the President's speech."
# spacy entities:
# 	Middle Eastern
# target entities:
# target events:
#
# This document is based exclusively on the content and behavior of selected foreign public media.
# spacy entities:
# target entities:
# target events:
#
# It is issued without coordination with other U.S. Government components.
# spacy entities:
# 	U.S. Government
# target entities:
# target events:
#
# Brazil and Germany call for implementation of Kyoto Protocol by September
# spacy entities:
# 	Brazil
# 	Germany
# 	September
# target entities:
# 	Protocol
# target events:
# 	implementation
#
# Brasilia, 14 (Agencia Brasil - ABr) - In a document entitled
# Partnership Brasil-Germany: Action Plan, both countrires have
# expressed interest in seeing the Kyoto Protocol take effect by
# the Sustainable Development Summit (Rio+10), that takes place in
# South Africa, next September.
# spacy entities:
# 	Brasilia
# 	14
# 	Agencia Brasil - ABr
# 	Partnership Brasil-Germany:
# 	the Kyoto Protocol
# 	the Sustainable Development Summit (Rio+10
# 	South Africa
# 	next September
# target entities:
# 	Protocol
# target events:
# 	take
#
# Brazil and Germany also call on
# other countries to ratify the protocol and work to enforce it.
# spacy entities:
# 	Brazil
# 	Germany
# target entities:
# 	protocol
# 	it
# target events:
# 	ratify
# 	work
# 	enforce
#
# The document also states that Brazil and Germany intend to
# expand cooperation in the area of environment and sustainable
# development.
# spacy entities:
# 	Brazil
# 	Germany
# target entities:
# target events:
#
# Both countries expect to present common positions
# at the Rio+10 meeting.
# spacy entities:
# 	Rio+10
# target entities:
# target events:
#
# Finally, the document stresses the
# importance of the Pilot Program for Protection of Tropical
# Forests (PPG-7) and German participation in the program.
# spacy entities:
# 	the Pilot Program for Protection of Tropical Forests
# 	PPG-7
# 	German
# target entities:
# target events:
#
# In perfect agreement with the latest polls on the popularity of President Hugo Chavez, the most recent study by Alfredo Keller has confirmed the resounding and sustained fall of the approval rating the President had at the beginning of his administration.
# spacy entities:
# 	Hugo Chavez
# 	Alfredo Keller
# target entities:
# 	Chavez
# 	President
# target events:
#
# The study was conducted among a sample of 1,000 adults from different socioeconomic groups in Caracas, Maracaibo, Valencia, San Cristobal, Barquisimeto, Maracay, Barcelona, Puerto La Cruz, Puerto Ordaz, and Maturin.
# spacy entities:
# 	1,000
# 	Caracas
# 	Maracaibo
# 	Valencia
# 	San Cristobal
# 	Barquisimeto
# 	Maracay
# 	Barcelona
# 	Puerto La Cruz
# 	Puerto Ordaz
# 	Maturin
# target entities:
# target events:
#
# The most telling result is that more than half of those polled believe that it is necessary to remove Chavez from office to solve the crisis.
# spacy entities:
# 	more than half
# 	Chavez
# target entities:
# 	Chavez
# target events:
# 	crisis
#
# From this group, 49 percent believe that a hypothetical replacement of the chief of state should take place through the institutional channels, whereas 5 percent agree with using forceful means.
# spacy entities:
# 	49 percent
# 	5 percent
# target entities:
# 	chief
# target events:
#
# Against this 54 percent, 43 percent of those polled prefer to let him govern until the end of his term in 2007.
# spacy entities:
# 	this 54 percent
# 	43 percent
# 	2007
# target entities:
# target events:
# 	let
# 	govern
#
# The recorded trend on the President's approval rating also registered a drop.
# spacy entities:
# target entities:
# target events:
#
# Whereas his approval rating reached 84 percent and his disapproval rating reached 11 percent in April 1999, both ratings crossed one another at 46 percent in August of this year.
# spacy entities:
# 	84 percent
# 	11 percent
# 	April 1999
# 	46 percent
# 	August of this year
# target entities:
# target events:
#
# This November, his disapproval rating reached 58 percent and his approval rating, 33 percent.
# spacy entities:
# 	This November
# 	58 percent
# 	33 percent
# target entities:
# target events:
#
# This result also reflects the collapse of the myth of a polarization between rich and poor, which applied at the beginning of his administration.
# spacy entities:
# target entities:
# target events:
#
# According to this, only 20 percent believe the rich and powerful are against Chavez.
# spacy entities:
# 	only 20 percent
# 	Chavez
# target entities:
# target events:
#
# However, 78 percent of those polled believe there are many poor who oppose him.
# spacy entities:
# 	78 percent
# target entities:
# 	him
# target events:
#
# This study shows a very clear pronouncement in favor of calling a referendum to redraft the Constitution and restore the balance of power: 75 percent agreed with the referendum, whereas 20 percent rejected it.
# spacy entities:
# 	Constitution
# 	75 percent
# 	20 percent
# target entities:
# 	balance
# target events:
# 	calling
# 	referendum
# 	redraft
# 	restore
#
# Although Chavez' edge in voter's preference continues to shrink, the effects of a divided opposition still keep him in first place (which shows the strength of radical Chavez supporters).
# spacy entities:
# 	Chavez
# 	first
# 	Chavez
# target entities:
# 	Chavez
# 	him
# 	Chavez
# target events:
#
# Given several names of possible presidential candidates, 25 percent voted for the current leader; 21 percent for Henrique Salas Romer; 16 percent for Julio Borges; 13 percent for Alfredo Pena; and 5 percent for Francisco Arias Cardenas.
# spacy entities:
# 	25 percent
# 	21 percent
# 	Henrique Salas Romer
# 	16 percent
# 	Julio Borges
# 	13 percent
# 	Alfredo Pena
# 	5 percent
# 	Francisco Arias Cardenas
# target entities:
# target events:
#
# [Caracas El Universal (Internet version) in Spanish on 8 December carries a related 153-word report that indicates: "The latest polls conducted by four of the country's leading firms show a drop in the popularity of President Hugo Chavez.
# spacy entities:
# 	[Caracas El Universal
# 	Spanish
# 	8 December
# 	four
# 	Hugo Chavez
# target entities:
# target events:
#
# According to Datanalisis' November poll, 57.4 percent of those polled feel as bad or worse than in the past and 55.3 percent believe their main problems are in the economic area.
# spacy entities:
# 	Datanalisis
# 	November
# 	57.4 percent
# 	55.3 percent
# target entities:
# target events:
#
# The population's disapproval of the government's job reaches 93 and 88.4 percent on the insecurity and unemployment problems, respectively.
# spacy entities:
# 	93
# 	88.4 percent
# target entities:
# target events:
#
# If the elections were held tomorrow, Chavez would still win, but his lead collapsed from 40 to 24 percent.
# spacy entities:
# 	tomorrow
# 	Chavez
# 	40 to 24 percent
# target entities:
# target events:
#
# Popular support for [Caracas Mayor Alfredo) Pena climbed from 5.5 to 16.8 percent."
# spacy entities:
# 	5.5 to 16.8 percent
# target entities:
# target events:
#
# Caracas El Universal (Internet version) in Spanish on 9 December carries a related 684-word report that indicates: "According to Luis Christiansen, director of Consultores 21 polling firm, President Chavez is facing two of the four key ingredients for the decline of any government: Unresolved major problems and a drop in the leader's popularity.
# spacy entities:
# 	Caracas El Universal
# 	Spanish
# 	9 December
# 	Luis Christiansen
# 	Consultores 21
# 	Chavez
# 	two
# 	four
# target entities:
# target events:
#
# The third is the perception of the President as an incapable leader, which is already happening, and the fourth is that Venezuelans are able to find a substitute leader.
# spacy entities:
# 	third
# 	fourth
# 	Venezuelans
# target entities:
# target events:
#
# The first factor deals with the nation's general mood.
# spacy entities:
# 	first
# target entities:
# target events:
#
# Venezuelans' level of optimism is currently the same reported in 1998; that is, they are feeling pessimistic.
# spacy entities:
# 	Venezuelans
# 	1998
# target entities:
# target events:
#
# The difference is back then, Chavez' candidacy raised expectations.
# spacy entities:
# 	Chavez
# target entities:
# target events:
#
# This lasted two years and people are feeling pessimistic again.
# spacy entities:
# 	two years
# target entities:
# target events:
#
# To the president's misfortune, 80 percent of Venezuelans believe there is a solution for the unemployment problem.
# spacy entities:
# 	80 percent
# 	Venezuelans
# target entities:
# target events:
#
# As Christiansen explains, 'if Venezuelans did not see unemployment as a problem that could be solved, they would not blame it on Chavez' incapacity.
# spacy entities:
# 	Christiansen
# 	Venezuelans
# 	Chavez
# target entities:
# 	incapacity
# target events:
# 	it
# 	unemployment
#
# Four of every 10 Venezuelans are blaming this problem on him.'
# spacy entities:
# 	Four
# 	10
# 	Venezuelans
# target entities:
# 	him
# 	problem
# 	him
# 	problem
# target events:
#
# As for the second factor, 43 percent find nothing positive in the government's actions.
# spacy entities:
# 	second
# 	43 percent
# target entities:
# 	government
# target events:
# 	actions
#
# Chavez' strengths include his personal qualities (27 percent) and clear desire to work (17 percent).
# spacy entities:
# 	Chavez
# 	27 percent
# 	17 percent
# target entities:
# target events:
# 	work
#
# In other words, Christiansen points out these are the strengths of a campaigning candidate instead of a president with three years in office.
# spacy entities:
# 	Christiansen
# 	three years
# target entities:
# target events:
#
# The fact that two-thirds of Venezuelans consider Chavez responsible for the country's problems shows that he is losing strength in the third aspect of stability: The President's ability to keep hope is shrinking.
# spacy entities:
# 	two-thirds
# 	Venezuelans
# 	Chavez
# 	third
# target entities:
# 	problems
# 	Chavez
# 	Chavez
# target events:
#
# Finally, the Consultores 21 analyst notes that today, the number of extreme Chavez opponents (42 percent) is larger than that of extreme Chavez supporters (18 percent), which could bring about a confrontation for power.
# spacy entities:
# 	21
# 	today
# 	Chavez
# 	42 percent
# 	Chavez
# 	18 percent
# target entities:
# target events:
#
# He added that Chavez still leads voter's preference with 28 percent."]
# spacy entities:
# 	Chavez
# 	28 percent
# target entities:
# 	Chavez
# target events:
#
# Why Kyoto is a rip-off
# spacy entities:
# target entities:
# 	Kyoto
# target events:
#
# According to a study released last week by the Canadian
# Manufacturers and Exporters, implementation of the 1997 Kyoto
# global warming treaty would cost our economy 450,000 jobs and as
# much as $40-billion.
# spacy entities:
# 	last week
# 	Canadian
# 	1997
# 	Kyoto
# 	450,000
# 	as much as $40-billion
# target entities:
# target events:
#
# But Jean Chretien is not worried.
# spacy entities:
# 	Jean Chretien
# target entities:
# target events:
#
# "I don't
# accept these figures," the Prime Minister said.
# spacy entities:
# target entities:
# target events:
#
# "There is
# nothing to be gained by frightening people when all the facts
# are not known."
# spacy entities:
# target entities:
# target events:
#
# But the $40-billion figure, far from being conceived to
# "frighten" Canadians, is plucked straight from government
# documents.
# spacy entities:
# 	$40-billion
# 	Canadians
# target entities:
# target events:
#
# According to a report released in 2000 by the
# National Air Issues Co-ordinating Committee on Climate Change, a
# group staffed by officials from the federal, provincial and
# territorial governments, hitting Canada's Kyoto target may mean
# "the loss of roughly one year's growth, or, viewed in absolute
# terms, in 2010, the loss in annual economic output of
# approximately $40-billion (or $1,100 per capita)."
# spacy entities:
# 	2000
# 	the National Air Issues Co-ordinating Committee on Climate Change
# 	Canada
# 	Kyoto
# 	roughly one year's
# 	2010
# 	annual
# 	approximately $40-billion
# 	1,100
# target entities:
# target events:
#
# This is not a price worth paying.
# spacy entities:
# target entities:
# target events:
#
# Governments are expected to
# protect the national economy, and they should deviate from that
# mission only when crucial national interests are at stake
# (fighting terrorism, for example).
# spacy entities:
# target entities:
# target events:
#
# Yet rising temperatures pose
# little threat to Canada.
# spacy entities:
# 	Canada
# target entities:
# target events:
#
# In its authoritative Feb., 2001, report
# on the projected impacts of global warming, the
# Intergovernmental Panel on Climate Change identified several
# threats to Canadian ecosystems, but concluded that our farmers
# would generally benefit from warmer temperatures.
# spacy entities:
# 	Feb., 2001
# 	the Intergovernmental Panel on Climate Change
# 	Canadian
# target entities:
# 	Panel
# 	report
# target events:
# 	concluded
# 	temperatures
#
# (Non-farming
# Canadians, most of whom spend at least part of the winter months
# scraping ice off their cars, chopping firewood and shovelling
# their walks, will profit as well.)
# spacy entities:
# 	Canadians
# 	the winter months
# target entities:
# target events:
# 	profit
#
# As for the globally felt benefits that would follow from
# Canada's implementation of the Kyoto protocol, they are slight.
# spacy entities:
# 	Canada
# 	Kyoto
# target entities:
# 	benefits
# 	they
# target events:
#
# By 2010, our $40-billion sacrifice would yield an expected
# reduction in annual carbon and carbon-equivalent emissions of
# about 46-million tonnes -- just 1/200th of the world's total
# projected greenhouse gas output.
# spacy entities:
# 	2010
# 	40-billion
# 	annual
# 	about 46-million tonnes
# target entities:
# 	sacrifice
# 	sacrifice
# target events:
#
# Even if Canada managed to convince the United States and every
# other Kyoto signatory to ratify the protocol, world carbon
# dioxide emissions would still soar.
# spacy entities:
# 	Canada
# 	the United States
# 	Kyoto
# target entities:
# target events:
#
# According to the U.S. Energy
# Information Administration, world energy consumption will
# increase by about 60% between now and 2020, with most of the
# upsurge expected to come from developing nations, which are not
# covered by the Kyoto Protocol.
# spacy entities:
# 	the U.S. Energy Information Administration
# 	about 60%
# 	between now and 2020
# 	the Kyoto Protocol
# target entities:
# target events:
#
# Under the fully implemented
# treaty, carbon dioxide emissions would grow 26% during the
# 1990-2010 period.
# spacy entities:
# 	26%
# 	1990-2010
# target entities:
# target events:
#
# Without Kyoto, the figure would be 34%.
# spacy entities:
# 	Without Kyoto
# 	34%
# target entities:
# target events:
#
# The
# worldwide cost of that 8% dip: about $2-trillion in lost GDP --
# give or take a trillion.
# spacy entities:
# 	8%
# 	about $2-trillion
# target entities:
# 	cost
# 	$ 2-trillion
# target events:
#
# There are better ways to spend that money.
# spacy entities:
# target entities:
# 	ways
# target events:
#
# Instead of trying to
# cap carbon dioxide emissions -- a costly burden at home and an
# impossible task in the developing world -- we should focus on
# abating the damage global warming does in at-risk nations.
# spacy entities:
# target entities:
# target events:
# 	task
# 	burden
# 	cap
# 	trying
# 	cap
# 	trying
#
# If
# scientists are correct, higher temperatures and rising sea
# ...
# target entities:
# target events:
#
# The convention was designed to unite efforts to prevent dangerous climate changes and to achieve a stabilization of the content of greenhouse gases in the atmosphere at a relatively safe level.
# spacy entities:
# target entities:
# target events:
#
# A decision was adopted at the first conference of convention participants (1995, Berlin) to begin phased actions to restrict emissions of greenhouse gases and to create an appropriate system of ecological-economic relations.
# spacy entities:
# 	first
# 	1995
# 	Berlin
# target entities:
# target events:
#
# Facts
# spacy entities:
# target entities:
# target events:
#
# Six greenhouse gases are known.
# spacy entities:
# 	Six
# target entities:
# target events:
#
# The principal one is CO2 (it is responsible for 80 percent of the greenhouse effect).
# spacy entities:
# 	CO2
# 	80 percent
# target entities:
# target events:
#
# Methane's contribution is 15 percent.
# spacy entities:
# 	Methane
# 	15 percent
# target entities:
# target events:
#
# Facts
# spacy entities:
# target entities:
# target events:
#
# According to estimates by the Ministry of Economic Development and the Ministry of Energy, Russia's total carbon-dioxide emissions in 2008-2012 will be 20 percent below the 1990 level.
# spacy entities:
# 	the Ministry of Economic Development
# 	the Ministry of Energy
# 	Russia
# 	2008-2012
# 	20 percent
# 	1990
# target entities:
# target events:
#
# This means that Russia will be able to offer the carbon market emission quotas of up to 3 billion tons.
# spacy entities:
# 	Russia
# 	up to 3 billion tons
# target entities:
# target events:
#
# The cash equivalent could be several tens of billions of dollars.
# spacy entities:
# 	several tens of billions of dollars
# target entities:
# target events:
#
# Background
# spacy entities:
# target entities:
# target events:
#
# The Ecological-Economic Meaning of the Kyoto Protocol
# spacy entities:
# 	The Ecological-Economic Meaning of the Kyoto Protocol
# target entities:
# target events:
#
# This is the first international document that makes use of the market mechanism as an approach to solving global ecological problems.
# spacy entities:
# 	first
# target entities:
# target events:
#
# It provides for economic mechanisms of international cooperation.
# spacy entities:
# target entities:
# target events:
#
# In Russia, up to 98 percent of all emissions of the main greenhouse gas -- CO2 -- come from the burning of fossil fuels (coal, oil, gas).
# spacy entities:
# 	Russia
# 	up to 98 percent
# target entities:
# target events:
#
# This means the problem of reducing emissions is a problem of energy efficiency and energy saving.
# spacy entities:
# target entities:
# target events:
#
# So far this potential has been utilized only to a small degree, whereas there are almost no such reserves left in the EU countries and Japan.
# spacy entities:
# 	EU
# 	Japan
# target entities:
# target events:
#
# That is why carrying out a project and reducing emissions in Russia is far cheaper than in most developed countries.
# spacy entities:
# 	Russia
# target entities:
# target events:
#
# The Obligations of Foreign Countries Under the Kyoto Protocol
# spacy entities:
# 	The Obligations of Foreign Countries
# 	the Kyoto Protocol
# target entities:
# target events:
#
# Developed countries and transitional economies must reduce emissions of greenhouse gases by 2008-2012 by at least 5 percent from the recognized baseline year of 1990.
# spacy entities:
# 	2008-2012
# 	at least 5 percent
# 	year of 1990
# target entities:
# target events:
#
# The reduction level varies.
# spacy entities:
# target entities:
# target events:
#
# The US, Japan and members of the EU must reduce emissions by 7, 6 and 8 percent from the 1990 level.
# spacy entities:
# 	US
# 	Japan
# 	EU
# 	7
# 	6
# 	8 percent
# 	1990
# target entities:
# target events:
#
# A limitation, rather than reduction, of emissions is specified for several developed countries (New Zealand, Norway), and Australia and Iceland received the right to increase emissions.
# spacy entities:
# 	New Zealand
# 	Norway
# 	Australia
# 	Iceland
# target entities:
# target events:
#
# If a country fails to use up its quota, it can sell the "surplus."
# spacy entities:
# target entities:
# target events:
#
# Russia's Obligations Under the Kyoto Protocol
# spacy entities:
# 	Russia
# 	Obligations Under the Kyoto Protocol
# target entities:
# target events:
#
# They are relatively mild for our country.
# spacy entities:
# target entities:
# target events:
#
# We are not required to reduce emissions, but over five years (from 2008 through 2012) we do not have the right to exceed their volume.
# spacy entities:
# 	five years
# 	2008 through
# 	2012
# target entities:
# target events:
#
# This approach is based on the fact that Russia's emissions today are almost 25 percent lower than in 1990, and, according to forecasts, the baseline level will not be reached in the next 10 years.
# spacy entities:
# 	Russia
# 	today
# 	almost 25 percent
# 	1990
# 	the next 10 years
# target entities:
# target events:
#
# This is substantiated in detail in the RF Energy Strategy Until 2020, which the government has adopted.
# spacy entities:
# 	2020
# target entities:
# target events:
#
# Within the framework of the protocol our country must maintain records of, and monitor, emissions and emission quotas, as well as regulate quotas.
# spacy entities:
# target entities:
# target events:
#
# This requires creating a national system of inventorying emissions and establishing a special registration center to maintain records of quotas.
# spacy entities:
# target entities:
# target events:
#
# Despite the outward complexity of the task, the creation of a record-keeping and monitoring system is neither very complicated nor very expensive, since the Goskomstat [State Statistical Committee] reporting forms that enterprises fill out contain virtually complete data.
# spacy entities:
# 	Goskomstat
# 	State Statistical Committee
# target entities:
# target events:
#
# Experts' Opinion
# spacy entities:
# target entities:
# target events:
#
# No One Will Be Well Off
# spacy entities:
# target entities:
# target events:
#
# Should we be happy about climate change?
# spacy entities:
# target entities:
# 	change
# 	change
# target events:
#
# Many people in Russia say: how much fuel we'll save!
# spacy entities:
# 	Russia
# target entities:
# target events:
# 	save
#
# But the warming will definitely not be uniform.
# spacy entities:
# target entities:
# target events:
#
# If the mean temperature rises by 2 degrees, the range of fluctuations will widen and will go, for example, from -40 to +45 degrees.
# spacy entities:
# 	2 degrees
# target entities:
# target events:
#
# So there will not be less of a need for fuel if, on the average, one winter out of every three winters becomes much colder than the harshest previous one.
# spacy entities:
# 	one
# 	three
# target entities:
# target events:
#
# And what will happen during the new, overly warm summer seasons?
# spacy entities:
# 	summer seasons
# target entities:
# 	seasons
# target events:
#
# What will happen to industrial and transport facilities, housing and other infrastructure that were built in permafrost, which will turn into muddy swamp?
# spacy entities:
# target entities:
# target events:
# 	turn
#
# The unbalancing of the climate will have a very negative effect on ecosystems.
# spacy entities:
# target entities:
# 	unbalancing
# 	effect
# 	unbalancing
# target events:
#
# Some species are disappearing, while others, conversely, are starting to multiply will unprecedented speed.
# spacy entities:
# target entities:
# target events:
#
# Gangster species are appearing, such as the locust, which is moving toward the north, where it has never been before.
# spacy entities:
# target entities:
# target events:
# 	appearing
#
# It is hard to say today what will happen to edaphic microflora, which is of fundamental importance to soil fertility.
# spacy entities:
# 	today
# 	microflora
# target entities:
# target events:
#
# If microflora stop reproducing humus, the higher plants will die, agricultural crops will stop growing, and timber will start to dry up.
# spacy entities:
# 	microflora
# target entities:
# target events:
#
# If the glaciers of Antarctica and Greenland melt down, the level of the world's oceans will rise.
# spacy entities:
# 	Antarctica
# 	Greenland
# target entities:
# target events:
#
# Russia has quite a lot of low-lying areas, such as St. Petersburg.
# spacy entities:
# 	Russia
# 	St. Petersburg
# target entities:
# target events:
#
# The enormous territory of Western Siberia risks turning into a sea.
# spacy entities:
# 	Western Siberia
# target entities:
# target events:
#
# All of Our Activities Are Ruining Nature
# spacy entities:
# target entities:
# target events:
#
# There are several models today, and they answer the question of why the climate is changing with varying degrees of persuasiveness.
# spacy entities:
# 	today
# target entities:
# target events:
#
# Why don't I have the sense that the models explain everything?
# spacy entities:
# target entities:
# target events:
#
# The problem is that the present stage of study of small climatic models has scientists studying the life of the models as the life of a real climatic system.
# spacy entities:
# target entities:
# target events:
#
# But to what extent does this reflect real life?
# spacy entities:
# target entities:
# target events:
#
# Nevertheless, the progress in gaining knowledge has been tremendous.
# spacy entities:
# target entities:
# target events:
#
# Our institute, along with the Institute of Systems Analysis and the Russian Academy of Sciences Computer Center, has begun studying the role of climate change in individual regions of Russia in order to forecast economic development.
# spacy entities:
# 	the Institute of Systems Analysis
# 	the Russian Academy of Sciences Computer Center
# 	Russia
# target entities:
# target events:
#
# There are no results to speak of yet, but it is important that this area of inquiry has appeared.
# spacy entities:
# target entities:
# target events:
#
# During a general warming, completely opposite phenomena take place.
# spacy entities:
# target entities:
# target events:
#
# In the polar regions, climate changes are more pronounced than in the middle latitudes.
# spacy entities:
# target entities:
# target events:
#
# As a result, the temperature doesn't change much in the equatorial and middle latitudes but changes a great deal in the polar regions.
# spacy entities:
# target entities:
# target events:
#
# What does this lead to?
# spacy entities:
# target entities:
# target events:
#
# Dispersion is less active, and so-called obstruction or stagnant situation manifest themselves in the atmosphere more and more often.
# spacy entities:
# target entities:
# target events:
#
# We have just observed such a case of a very lengthy thaw in the center of Russia.
# spacy entities:
# 	Russia
# target entities:
# target events:
#
# Incidentally, last year's incredibly cold winter in Primorskiy Kray was very possibly an example of the same property.
# spacy entities:
# 	last year's
# 	winter
# 	Primorskiy Kray
# target entities:
# target events:
#
# Because, strange as it may seem, prolonged, stagnant cold spells are also a result of global warming when there is less ventilation of the atmosphere as a whole.
# spacy entities:
# target entities:
# target events:
#
# As for all the ideas regarding blocking shields, umbrellas and the like, I will answer this way.
# spacy entities:
# target entities:
# target events:
#
# The Kyoto Protocol proposes adapting to climate change.
# spacy entities:
# 	The Kyoto Protocol
# target entities:
# target events:
#
# There are no proposals there to erect screens or to shoot cooling aerosols into the atmosphere.
# spacy entities:
# target entities:
# target events:
#
# Already everything humankind does causes incredible damage to nature.
# spacy entities:
# target entities:
# target events:
#
# We emit greenhouse gases, we thaw out the frozen regions that emit methane, we destroy forests, and in the south, deserts are expanding, a process that alters the heat exchange between the earth's surface and the atmosphere.
# spacy entities:
# 	earth
# target entities:
# target events:
#
# That is, all of our actions are accompanied by a deterioration in the climate.
# spacy entities:
# target entities:
# target events:
#
# In this situation it is very frightening to do anything else -- for example, to suspend some umbrella, screen or something else in that vein.
# spacy entities:
# target entities:
# target events:
#
# Elaborating on the 'axis of evil'
# spacy entities:
# target entities:
# target events:
#
# PRESIDENT GEORGE Bush's National Security Adviser Condoleezza
# Rice has recently "defined" the context and scope of the term
# "axis of evil" that Bush used in his State of the Union address
# a few weeks ago to describe Iraq, Iran and North Korea.
# spacy entities:
# 	GEORGE Bush's
# 	Condoleezza Rice
# 	Bush
# 	a few weeks ago
# 	Iraq
# 	Iran
# 	North Korea
# target entities:
# 	axis
# 	Iraq
# 	Iran
# 	Korea
# 	axis
# 	Iraq
# 	Iran
# 	Korea
# target events:
#
# The
# criteria set by Rice are the following: the three countries in
# question are repressive and grave human rights violators, and
# aggressively seeking weapons of mass destruction.
# spacy entities:
# 	Rice
# 	three
# target entities:
# 	countries
# target events:
# 	seeking
# 	violators
#
# By all conservative estimates, there are scores of other
# countries which can easily qualify as repressive and violating
# human rights.
# spacy entities:
# target entities:
# target events:
#
# The rule, as far as human rights are concerned, is
# that every nation which does not enjoy pluralistic democracy is
# violating human rights and is therefore oppressive.
# spacy entities:
# target entities:
# 	rule
# target events:
#
# There are
# many countries in the world that hardly qualify as pluralistic
# democracies.
# spacy entities:
# target entities:
# target events:
#
# On this count, the national security adviser may
# have erred.
# spacy entities:
# target entities:
# target events:
#
# As for her wording regarding acquisition of weapons, what is
# particularly noteworthy is the use of the words "aggressively
# seeking" nuclear, biological or chemical weapons.
# spacy entities:
# target entities:
# target events:
#
# In other
# words, countries which are seeking or developing such arsenal at
# a slow pace do not seem to come within the scope of the "axis of
# evil".
# spacy entities:
# target entities:
# target events:
#
# One can name more than a dozen countries which are
# contemplating the acquisition of mass destruction weapons at one
# speed or another.
# spacy entities:
# 	more than a dozen
# 	one
# target entities:
# 	weapons
# target events:
# 	acquisition
#
# All other countries which are seemingly
# refraining from acquiring such weapons are doing so not so much
# to escape being branded as "evil" but rather because they have
# neither the knowledge nor the money to join the "nuclear club".
# spacy entities:
# target entities:
# target events:
#
# Come to think of it, acquiring weapons of mass destruction per
# se may not be a correct basis for judging whether a nation is
# good or evil.
# spacy entities:
# target entities:
# target events:
#
# The mere development or possession of mass
# destruction weapons is not in itself a reason to label a state
# as evildoer.
# spacy entities:
# target entities:
# 	state
# target events:
#
# After all, the US is the first nation to have
# developed nuclear weapons.
# spacy entities:
# 	US
# 	first
# target entities:
# target events:
#
# Moreover, the US is the first and
# only nation ever to deploy such weapons.
# spacy entities:
# 	US
# 	first
# target entities:
# target events:
#
# Perhaps the real criterion in this context is whether the
# nuclear country is democratic in every sense of the word.
# spacy entities:
# target entities:
# target events:
#
# Washington seems to be particularly disturbed and feel that its
# own national security is being threatened only when the nations
# which acquire mass destruction weapons are authoritarian or
# repressive, irrespective of the pace of amassing weaponry.
# spacy entities:
# 	Washington
# target entities:
# target events:
# 	are
# 	are
#
# This
# is, in fact, the fear of all countries, as they feel that
# democratic regimes are more restrained and responsible when it
# comes to resorting to weapons of mass destruction.
# spacy entities:
# target entities:
# target events:
# 	This
#
# If this is
# the case, Rice could have elaborated more precise criteria for
# membership in the "axis of evil," by establishing more clearly
# the connection between the nature of the regime and the
# acquisition of weapons of mass destruction.
# spacy entities:
# 	Rice
# target entities:
# target events:

# %%
ent
# Out:
# 'Rice'

# %%
type(ent)
# Out:
# str

# %%
text = "He lives in New York by the riverside."

# %%
doc = nlp(text)

# %%
for ent in doc.ents:
    print(ent)
# Out:
# New York

# %%
ent.start
# Out:
# 3

# %%
ent.end
# Out:
# 5

# %%
for nc in doc.noun_chunks:
    print(nc.root.i)
# Out:
# 0
# 4
# 7

# %%
n_target_entities, n_target_events = 0, 0
n_target_entities_outside_target_span, n_target_events_outside_target_span = 0, 0

d = 2

n_target_entities_covered_by_spacy_entities, n_within_span_target_entities_covered_by_spacy_entities, n_spacy_entities = 0, 0, 0
n_target_entities_covered_by_spacy_noun_chunk_heads, n_within_span_target_entities_covered_by_spacy_noun_chunk_heads, n_spacy_noun_chunk_heads = 0, 0, 0
n_target_entities_covered_by_d_spacy_noun_chunk_heads, n_d_spacy_noun_chunk_heads = 0, 0

n_within_span_target_events_covered_by_spacy_verb, n_spacy_verbs = 0, 0
n_target_events_covered_by_d_spacy_verbs, n_d_spacy_verbs = 0, 0

for doc in mpqa3_docs:
    for sentence in doc:
        
        target_spans, target_entities, target_events = set(), set(), set()
        spacy_entities, spacy_noun_chunk_heads, spacy_verbs = set(), set(), set()
        d_spacy_noun_chunk_heads, d_spacy_verbs = set(), set()
        target_entities_outside_target_span, target_events_outside_target_span = set(), set()

        for ex in sentence["dse"]:
            if ex["target-type"] == "span":
                target_spans.add(tuple(ex["target"]))
            elif ex["target-type"] == "entity":
                target_entities.add(tuple(ex["target"]))
            else:
                target_events.add(tuple(ex["target"]))
        
        for ent in target_entities:
            for span in target_spans:
                if span[0] <= ent[0] <= ent[1] <= span[1]:
                    break
            else:
                target_entities_outside_target_span.add(ent)

        for event in target_events:
            for span in target_spans:
                if span[0] <= event[0] <= event[1] <= span[1]:
                    break
            else:
                target_events_outside_target_span.add(event)
        
        for ent in sentence["spacy_doc"].ents:
            entity = (ent.start, ent.end - 1)
            for span in target_spans:
                if span[0] <= entity[0] <= entity[1] <= span[1]:
                    spacy_entities.add(entity)
                    break
        
        for noun_chunk in sentence["spacy_doc"].noun_chunks:
            head = (noun_chunk.root.i, noun_chunk.root.i)
            for span in target_spans:
                if span[0] <= head[0] <= span[1]:
                    spacy_noun_chunk_heads.add(head)
                    break
            for span in target_spans:
                if span[0] - d <= head[0] <= span[1] + d:
                    d_spacy_noun_chunk_heads.add(head)
                    break
        
        for token in sentence["spacy_doc"]:
            if token.pos_ == "VERB":
                verb = (token.i, token.i)
                for span in target_spans:
                    if span[0] <= verb[0] <= span[1]:
                        spacy_verbs.add(verb)
                        break
                for span in target_spans:
                    if span[0] - d <= verb[0] <= span[1] + d:
                        d_spacy_verbs.add(verb)
                        break
        
        n_target_entities += len(target_entities)
        n_target_events += len(target_events)
        n_spacy_entities += len(spacy_entities)
        n_spacy_noun_chunk_heads += len(spacy_noun_chunk_heads)
        n_spacy_verbs += len(spacy_verbs)
        n_d_spacy_noun_chunk_heads += len(d_spacy_noun_chunk_heads)
        n_d_spacy_verbs += len(d_spacy_verbs)

        n_target_entities_outside_target_span += len(target_entities_outside_target_span)
        n_target_events_outside_target_span += len(target_events_outside_target_span)

        n_target_entities_covered_by_spacy_entities += len(target_entities.intersection(spacy_entities))
        n_target_entities_covered_by_spacy_noun_chunk_heads += len(target_entities.intersection(spacy_noun_chunk_heads))
        
        n_within_span_target_entities_covered_by_spacy_entities += len((target_entities.difference(target_entities_outside_target_span)).intersection(spacy_entities))
        n_within_span_target_entities_covered_by_spacy_noun_chunk_heads += len((target_entities.difference(target_entities_outside_target_span)).intersection(spacy_noun_chunk_heads))

        n_within_span_target_events_covered_by_spacy_verb += len((target_events.difference(target_events_outside_target_span)).intersection(spacy_verbs))

        n_target_entities_covered_by_d_spacy_noun_chunk_heads += len(target_entities.intersection(d_spacy_noun_chunk_heads))
        n_target_events_covered_by_d_spacy_verbs += len(target_events.intersection(d_spacy_verbs))

print("{:.2f} target entities lie outside target span".format(n_target_entities_outside_target_span/n_target_entities))
print("{:.2f} target events   lie outside target span".format(n_target_events_outside_target_span/n_target_events))
print("ner:                       precision = {:.2f}, recall = {:.2f}".format(n_target_entities_covered_by_spacy_entities/n_spacy_entities, n_target_entities_covered_by_spacy_entities/n_target_entities))
print("ner (within span):         precision = {:.2f}, recall = {:.2f}".format(n_within_span_target_entities_covered_by_spacy_entities/n_spacy_entities, n_within_span_target_entities_covered_by_spacy_entities/(n_target_entities - n_target_entities_outside_target_span)))
print("noun chunk:                precision = {:.2f}, recall = {:.2f}".format(n_target_entities_covered_by_spacy_noun_chunk_heads/n_spacy_noun_chunk_heads, n_target_entities_covered_by_spacy_noun_chunk_heads/n_target_entities))
print("noun chunk (within span):  precision = {:.2f}, recall = {:.2f}".format(n_within_span_target_entities_covered_by_spacy_noun_chunk_heads/n_spacy_noun_chunk_heads, n_within_span_target_entities_covered_by_spacy_noun_chunk_heads/(n_target_entities - n_target_entities_outside_target_span)))
print("noun chunk + d = {}:        precision = {:.2f}, recall = {:.2f}".format(d, n_target_entities_covered_by_d_spacy_noun_chunk_heads/n_d_spacy_noun_chunk_heads, n_target_entities_covered_by_d_spacy_noun_chunk_heads/n_target_entities))
print("spacy verb (within span):  precision = {:.2f}, recall = {:.2f}".format(n_within_span_target_events_covered_by_spacy_verb/n_spacy_verbs, n_within_span_target_events_covered_by_spacy_verb/(n_target_events - n_target_events_outside_target_span)))
print("spacy verb + d = {}:        precision = {:.2f}, recall = {:.2f}".format(d, n_target_events_covered_by_d_spacy_verbs/n_d_spacy_verbs, n_target_events_covered_by_d_spacy_verbs/n_target_events))
# Out:
# 0.30 target entities lie outside target span
# 0.55 target events   lie outside target span
# ner:                       precision = 0.20, recall = 0.12
# ner (within span):         precision = 0.20, recall = 0.17
# noun chunk:                precision = 0.35, recall = 0.63
# noun chunk (within span):  precision = 0.35, recall = 0.89
# noun chunk + d = 2:        precision = 0.31, recall = 0.68
# spacy verb (within span):  precision = 0.37, recall = 0.66
# spacy verb + d = 2:        precision = 0.24, recall = 0.49
